# %%
# necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#load the insurance sheet

dataframe = pd.read_csv('insurance.csv')
dataframe.shape
# Out:
# (1338, 7)

# %%
dataframe.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dataframe.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
dataframe.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %% [markdown]
# Checking the presence of missing values

# %%
dataframe.describe(include="all")
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %% [markdown]
# 5 point summary of numerical attributes

# %%
dataframe.drop('children',axis=1, inplace=True) 
dataframe
# Out:
#       age     sex     bmi smoker     region      charges
# 0      19  female  27.900    yes  southwest  16884.92400
# 1      18    male  33.770     no  southeast   1725.55230
# 2      28    male  33.000     no  southeast   4449.46200
# 3      33    male  22.705     no  northwest  21984.47061
# 4      32    male  28.880     no  northwest   3866.85520
# ...   ...     ...     ...    ...        ...          ...
# 1333   50    male  30.970     no  northwest  10600.54830
# 1334   18  female  31.920     no  northeast   2205.98080
# 1335   18  female  36.850     no  southeast   1629.83350
# 1336   21  female  25.800     no  southwest   2007.94500
# 1337   61  female  29.070    yes  northwest  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataframe.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000259BA940848>,
# ...
#       dtype=object)

# %% [markdown]
# Distribution of ‘bmi’, ‘age’ and ‘charges’ columns

# %%
dataframe.skew()
# Out:
# age        0.055673
# bmi        0.284047
# charges    1.515880
# dtype: float64

# %% [markdown]
# Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns

# %%
plt.figure(figsize = (20,10))
sns.boxplot(data = dataframe)

# %% [markdown]
# Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns

# %%
dataframe = pd.read_csv('insurance.csv')
dataframe
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dataframe.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000259BAB7C0C8>,
# ...
#       dtype=object)

# %% [markdown]
# Distribution of categorical columns (include children)

# %%
sns.pairplot(dataframe)

# %% [markdown]
# Pair plot that includes all the columns of the data frame

# %%
sns.stripplot(dataframe['smoker'], dataframe['charges'])

# %% [markdown]
# 4(a) - yes people who smoke their charges differ significantly , as you can see for smoker charges are moslty higher thane non-smoker

# %%
sns.factorplot(x="sex", 
               y="bmi", 
               hue="sex", 
               data=dataframe, 
               kind="swarm")

# %% [markdown]
# 4(b)- no bmi of males doesn't differ significantly from that of females

# %%
pd.crosstab(dataframe['smoker'],dataframe['sex'] )
# Out:
# sex     female  male
# smoker
# no         547   517
# yes        115   159

# %% [markdown]
# 4 (c) - in given data as compare to  female there are more male smoker 159-115=44

# %%
sns.barplot(dataframe['children'], dataframe['bmi'], hue=dataframe['sex'])

# %% [markdown]
# 4(d) - yes distribution of bmi across women with no children, one child and two children are the same
